# %% [markdown]
# # Deskriptiv Statistic

# %% [markdown]
# #### Imports

# %%
# Basic Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import repeat

# %%
bco = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/Brent_Crude_Oil')

# %%
bco.head()
# Out:
#          Date      Close  Log_Returns  Pred_Signal        RSI  K_percent  \
# 0  2007-08-16  69.769997    -0.026449            1  29.797228   9.756045
# 1  2007-08-17  70.440002     0.009557            0  37.710864  17.926851
# 2  2007-08-20  69.849998    -0.008411            0  33.868557  11.206854
# 3  2007-08-21  68.690002    -0.016746            1  27.466358   6.351211
# 4  2007-08-22  68.699997     0.000145            1  27.604705   6.649574
#
#        MACD       ROC
# 0 -0.572856 -0.066622
# 1 -0.563372 -0.010257
# 2 -0.584877 -0.027159
# 3 -0.665806 -0.032399
# 4 -0.718980 -0.021507

# %%
bco.tail()
# Out:
#             Date       Close  Log_Returns  Pred_Signal        RSI  K_percent  \
# 3636  2022-04-20  106.800003    -0.004205            1  49.397702  53.372104
# 3637  2022-04-21  108.330002     0.014224            0  52.951881  62.267448
# 3638  2022-04-22  106.650002    -0.015630            0  48.681002  52.500002
# 3639  2022-04-25  102.320000    -0.041447            1  39.143934  27.325569
# 3640  2022-04-26  104.989998     0.025760            1  46.863912  42.848816
#
#           MACD       ROC
# 3636  0.168811  0.056693
# 3637  0.216530  0.077053
# 3638  0.117432  0.037653
# 3639 -0.306961  0.038993
# 3640 -0.422973  0.003345

# %% [markdown]
# ## bco.info()

# %%
# Data Frame with the Classification relevant Columns
df = pd.DataFrame(data=(bco['RSI'],bco['K_percent'],bco['MACD'],
                              bco['ROC'], bco['Close'], bco['Log_Returns']))
df = df.T
df.head()
# Out:
#          RSI  K_percent      MACD       ROC      Close  Log_Returns
# 0  29.797228   9.756045 -0.572856 -0.066622  69.769997    -0.026449
# 1  37.710864  17.926851 -0.563372 -0.010257  70.440002     0.009557
# 2  33.868557  11.206854 -0.584877 -0.027159  69.849998    -0.008411
# 3  27.466358   6.351211 -0.665806 -0.032399  68.690002    -0.016746
# 4  27.604705   6.649574 -0.718980 -0.021507  68.699997     0.000145

# %%
ML_data = pd.DataFrame(data=(bco['RSI'],bco['K_percent'],bco['MACD'],
                              bco['ROC'], bco['Pred_Signal']))
ML_data = ML_data.T
ML_data.head()
# Out:
#          RSI  K_percent      MACD       ROC  Pred_Signal
# 0  29.797228   9.756045 -0.572856 -0.066622          1.0
# 1  37.710864  17.926851 -0.563372 -0.010257          0.0
# 2  33.868557  11.206854 -0.584877 -0.027159          0.0
# 3  27.466358   6.351211 -0.665806 -0.032399          1.0
# 4  27.604705   6.649574 -0.718980 -0.021507          1.0

# %% [markdown]
# ## Pairsplot Features

# %%
sns.pairplot(df)

# %%
sns.pairplot(ML_data)

# %%
cut = round(len(ML_data)*0.2)
ML_data_pred = ML_data[-cut:]
ML_data_pred.head()
# Out:
#             RSI  K_percent      MACD       ROC  Pred_Signal
# 2913  14.192999   8.464852 -2.079463 -0.145936          1.0
# 2914  24.211786  15.925378 -2.295324 -0.089876          1.0
# 2915  37.173946  27.546632 -2.309057 -0.078614          0.0
# 2916  33.229626  21.729159 -2.373274 -0.111539          0.0
# 2917  33.229626  22.593485 -2.396541 -0.103096          0.0

# %%
rand_sample = ML_data.sample(1000, axis=0)
rand_sample.head()
rand_sample.describe()
# Out:
#                RSI    K_percent         MACD          ROC  Pred_Signal
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     52.426793    55.050196     0.005844     0.002745     0.514000
# std      17.213376    31.775047     2.034307     0.071120     0.500054
# min       6.709996    -4.806678    -9.361451    -0.420555     0.000000
# 25%      39.799953    24.387867    -0.801597    -0.031672     0.000000
# 50%      53.972684    60.159469     0.271527     0.005271     1.000000
# 75%      64.953495    84.334977     1.289563     0.040993     1.000000
# max      90.435188   106.200867     7.119732     0.393343     1.000000

# %% [markdown]
# ## Lines Plot

# %%
# Featurs Plot

fig, axs = plt.subplots(3,2, figsize=(12,12))

axs[0, 0].plot(bco['Log_Returns'])
axs[0, 0].set_title('Log_Returns')

axs[0, 1].plot(bco['RSI'], 'tab:red')
axs[0, 1].set_title('RSI')

axs[1, 0].plot(bco['K_percent'], 'tab:green')
axs[1, 0].set_title('K_percent')

axs[1, 1].plot(bco['MACD'])
axs[1, 1].set_title('MACD')

axs[2, 0].plot(bco['ROC'], 'tab:green')
axs[2, 0].set_title('ROC')

axs[2, 1].plot(bco['Close'], 'tab:green')
axs[2, 1].set_title('Close')


for ax in axs.flat:
    ax.set(xlabel='Time', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# # Time Serie
# ## Descriptiv Statistik

# %% [markdown]
# ## Close Price Plot

# %%
plt.figure(figsize=(14,8))
plt.title('Brent Crude Oil Future Close Price in US Dollar($)', fontsize = 18)
plt.ylabel('Price in US Dollar ($)', fontsize = 14)
plt.xlabel('Time Steps', fontsize = 14)
plt.grid(True)
plt.plot(df.Close, label = 'Close Price', color = 'blue')
plt.plot(df.Close.rolling(200).mean(), label = 'MA200 Close Price', color = 'red')
plt.legend(loc='best', fontsize = 14)

# %%
plt.figure(figsize=(14,8))
plt.title('Brent Crude Oil Future Log Returns', fontsize = 18)
plt.ylabel('Log Returns', fontsize = 14)
plt.xlabel('Time Steps', fontsize = 14)
plt.grid(True)
plt.plot(df.Log_Returns, color = 'blue')

# %% [markdown]
# ### Price and Log Returns Box Plots

# %%
plt.figure(figsize=(14,8))
plt.title('Boxplot Brent Crude Oil Future Log Returns', fontsize = 18)
plt.xlabel('Log Returns', fontsize = 14)
sns.boxplot(df['Log_Returns'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Boxplot Brent Crude Oil Future Log Returns'}, xlabel='Log_Returns'>

# %% [markdown]
# ### Price and Log Returns Density Plots

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future Close Price ($)', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('Close Price ($)', fontsize = 14)
plt.grid(True)
sns.distplot(df['Close'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future Close Price ($)'}, xlabel='Close', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future Log Returns', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('Log Returns', fontsize = 14)
plt.grid(True)
sns.distplot(df['Log_Returns'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future Log Returns'}, xlabel='Log_Returns', ylabel='Density'>

# %% [markdown]
# ### Price and Log Returns Position measure

# %%
df_label = df.drop(['RSI','MACD', 'K_percent','ROC'], axis = 1)
print(df_label.describe(percentiles=[.05,.25,.5,.75,.95]))
# Out:
#              Close  Log_Returns
# count  3641.000000  3641.000000
# mean     77.408053     0.000105
# std      25.918687     0.024656
# min      19.330000    -0.279761
# 5%       41.290001    -0.037248
# 25%      55.980000    -0.009985
# 50%      73.360001     0.000435
# 75%     103.809998     0.011025
# 95%     117.099998     0.034635
# max     146.080002     0.274191

# %% [markdown]
# ### Quantile-Quantile Plot

# %%
import statsmodels.api as sm
import scipy.stats as stats

# %%
plt.figure(figsize=(18,10))
sm.qqplot(df.Log_Returns, line='s')
plt.title('QQ-Plot (Brent Crude Oil Future)')
plt.grid(True)
plt.show()

# %%
# QQ-Plot with T-Student Distribution
plt.figure(figsize=(18,10))
sm.qqplot(df.Log_Returns, dist = stats.t, distargs=(5,), line='s')# Seems like a t-Student Distribution with df = 5
plt.title('QQ-Plot (Brent Crude Oil Future)')
plt.xlabel('Theoretical Quantiles (t-Student with df = 5)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ACF Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
#plt.figure(figsize=(10,8))
plot_acf(df.Log_Returns, lags=30)
plt.title('ACF of Brent Crude Oil Future')
plt.ylabel('ACF')
plt.xlabel('Lag')
plt.grid(True)

# %% [markdown]
# ### Maximal Drawdown Plot

# %%
# Own MDD Function for GAN's Output
def own_MDD_GANs_plt(returns):
    
    # INPUT are RETURS values !!!!
    ##************************************************##
    # Cumulative Returns
    cum_returns = [returns[0]]
    for i in range(0, len(returns)-1):
        i = (1 + returns[i]) * (1 + returns[i+1]) - 1
        cum_returns.append(i)
    ##************************************************##
    # Drawdown
    drawdown = []
    for i in range(0,len(returns)):
        if returns[i] < 0:
            drawdown.append(returns[i])
        else:
            drawdown.append(0)
    
    return [drawdown]     
    ##************************************************##
    
    
MDD = own_MDD_GANs_plt(df.Log_Returns)

plt.figure(figsize=(14,8))
plt.title('Maximal Drawdown Plot', fontsize = 18)
plt.ylabel('Precent %', fontsize = 14)
plt.xlabel('Time', fontsize = 14)
plt.grid(True)
plt.plot(MDD[0])
plt.show()

# %%
# MDD Densityplot
plt.figure(figsize=(14,8))
plt.title('Maximal Drawdown Densityplot', fontsize = 18)
plt.ylabel('Frequency', fontsize = 14)
plt.xlabel('Percent (%)', fontsize = 14)
plt.grid(True)
sns.distplot(MDD[0])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Maximal Drawdown Densityplot'}, xlabel='Percent (%)', ylabel='Frequency'>

# %%
mdd = {'MDD':MDD[0]}
df_MDD = pd.DataFrame(data=mdd)

print(df_MDD.describe(percentiles=[.05,.25,.5,.75,.95]))
# Out:
#                MDD
# count  3641.000000
# mean     -0.007991
# std       0.016021
# min      -0.279761
# 5%       -0.037248
# 25%      -0.009985
# 50%       0.000000
# 75%       0.000000
# 95%       0.000000
# max       0.000000

# %% [markdown]
# ### Features Box Plots

# %%
plt.figure(figsize=(14,8))
plt.title('Boxplot Brent Crude Oil Future RSI', fontsize = 18)
plt.xlabel('RSI', fontsize = 14)
sns.boxplot(df['RSI'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Boxplot Brent Crude Oil Future RSI'}, xlabel='RSI'>

# %%
plt.figure(figsize=(14,8))
plt.title('Boxplot Brent Crude Oil Future MACD', fontsize = 18)
plt.xlabel('MACD', fontsize = 14)
sns.boxplot(df['MACD'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Boxplot Brent Crude Oil Future MACD'}, xlabel='MACD'>

# %%
plt.figure(figsize=(14,8))
plt.title('Boxplot Brent Crude Oil Future K %', fontsize = 18)
plt.xlabel('K %', fontsize = 14)
sns.boxplot(df['K_percent'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Boxplot Brent Crude Oil Future K %'}, xlabel='K_percent'>

# %%
plt.figure(figsize=(14,8))
plt.title('Boxplot Brent Crude Oil Future ROC', fontsize = 18)
plt.xlabel('ROC', fontsize = 14)
sns.boxplot(df['ROC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Boxplot Brent Crude Oil Future ROC'}, xlabel='ROC'>

# %% [markdown]
# ### Features Density Plots

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future RSI', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('RSI', fontsize = 14)
plt.grid(True)
sns.distplot(df['RSI'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future RSI'}, xlabel='RSI', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future MACD', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('MACD', fontsize = 14)
plt.grid(True)
sns.distplot(df['MACD'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future MACD'}, xlabel='MACD', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future K %', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('K %', fontsize = 14)
plt.grid(True)
sns.distplot(df['K_percent'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future K %'}, xlabel='K_percent', ylabel='Density'>

# %%
plt.figure(figsize=(14,8))
plt.title('Density Plot of Brent Crude Oil Future ROC', fontsize = 18)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('ROC', fontsize = 14)
plt.grid(True)
sns.distplot(df['ROC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Density Plot of Brent Crude Oil Future ROC'}, xlabel='ROC', ylabel='Density'>

# %%
df_feature = df.drop(['Close','Log_Returns'], axis = 1)

print(df_feature.describe(percentiles=[.05,.25,.5,.75,.95]))
# Out:
#                RSI    K_percent         MACD          ROC
# count  3641.000000  3641.000000  3641.000000  3641.000000
# mean     52.275425    54.728841     0.065906     0.003645
# std      17.264053    31.862231     2.022799     0.071429
# min       5.991848   -19.512141    -9.802775    -0.502300
# 5%       21.264264     4.352861    -3.694584    -0.109340
# 25%      40.587059    24.686536    -0.771373    -0.031050
# 50%      53.986244    58.669804     0.313472     0.006683
# 75%      65.289606    84.218291     1.352979     0.041847
# 95%      78.270572    97.386590     2.835581     0.104124
# max      91.607333   106.200867     8.275563     0.549275

# %% [markdown]
# # Performance Plot of all Models

# %%
# Imports
RF_Perf_data = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/RF_Perf_data')
LSTM_Perf_data = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/LSTM_Perf_data')
knn_Perf_data = pd.read_csv('//Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/knn_Perf_data')
SVM_Perf_data = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/SVM_Perf_data')
CS_Perf_data = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/CS_Perf_data')
AG_Perf_data = pd.read_csv('/Users/romaindeleze/Desktop/BSc/Romain_WI_TZ/8.Semester/BA/Daten/arma_garch_Perf_data')

# %%
CS_Perf_data=CS_Perf_data.dropna()

# %%
a = list(repeat(1, len(RF_Perf_data['RF_Perf_OL'])-len(LSTM_Perf_data['LSTM_Perf_OL'])))
a = np.array(a)

b = LSTM_Perf_data['LSTM_Perf_OL']
b = np.array(b)

c = LSTM_Perf_data['LSTM_Perf_LS']
c = np.array(c)

d = np.append(a,b)
e = np.append(a,c)

# %% [markdown]
# ## Only Long Plot

# %%
plt.figure(figsize=(18,10))
plt.title('Trading Performance Only Long', fontsize = 18)
plt.ylabel('Factor', fontsize = 14)
plt.xlabel('Time Step', fontsize = 14)
plt.grid(True)
plt.plot(RF_Perf_data['RF_Perf_OL'],label='RF', color = 'orange')
plt.plot(d, label='LSTM', color = 'blue')
plt.plot(knn_Perf_data['knn_Perf_OL'], label='k-NN', color = 'green')
plt.plot(knn_Perf_data['BaH_Perf'],label='Buy and Hold', color = 'red')
plt.plot(SVM_Perf_data['SVM_Perf_OL'],label='SVM', color = 'yellow')
plt.plot(CS_Perf_data['CS_Perf_OL'].values,label='Cross Signal', color = 'black')
plt.plot(AG_Perf_data['only_long'],label='ARMA GARCH', color = 'violet')
plt.legend(loc='best', fontsize = 14)

# %% [markdown]
# ## Long Short Plot

# %%
plt.figure(figsize=(18,10))
plt.title('Trading Performance Long Short', fontsize = 18)
plt.ylabel('Factor', fontsize = 14)
plt.xlabel('Time Step', fontsize = 14)
plt.grid(True)
plt.plot(RF_Perf_data['RF_Perf_LS'],label='RF', color = 'orange')
plt.plot(e, label='LSTM', color = 'blue')
plt.plot(knn_Perf_data['knn_Perf_LS'], label='k-NN', color = 'green')
plt.plot(knn_Perf_data['BaH_Perf'],label='Buy and Hold', color = 'red')
plt.plot(SVM_Perf_data['SVM_Perf_LS'],label='SVM', color = 'yellow')
plt.plot(CS_Perf_data['CS_Perf_LS'].values,label='Cross Signal', color = 'black')
plt.plot(AG_Perf_data['long_short'],label='ARMA GARCH', color = 'violet')
plt.legend(loc='best', fontsize = 14)

# %% [raw]
# ML_data_pred = rand_sample
# # 5D Visualisation Testdata ML
# %matplotlib notebook
# plt.figure(figsize=(10,8))
# ax = plt.axes(projection='3d')
# fg = ax.scatter3D(ML_data_pred['ROC'],ML_data_pred['RSI'],ML_data_pred['K_percent'],
#                   s=ML_data_pred['MACD']*np.exp(3), c=ML_data_pred['Pred_Signal'], alpha=.7,)
# ax.set_xlabel('ROC')
# ax.set_ylabel('RSI')
# ax.set_zlabel('% K')
# #ax.legend(fg.legend_elements()[0],list(set(ML_data_pred['Pred_Signal'])),title='Signal')
# plt.legend(*fg.legend_elements("sizes", num=6),title = '$MACD*e^3$ (Size)')
# plt.colorbar(fg)
